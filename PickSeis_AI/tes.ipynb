# %%
from seisbench.data.stead import STEAD

dataset = STEAD()
window_length = 4000  # misal, ubah ke 4000 sample
dataset.set_input_window(window_length)
# Out:
# 2025-05-15 17:05:28,340 | seisbench | WARNING | Dataset STEAD not in cache.
# 2025-05-15 17:05:28,371 | seisbench | WARNING | Trying to download preprocessed version from SeisBench repository.
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from seisbench.data.stead import STEAD
# ----> 3 dataset = STEAD()
#       4 window_length = 4000  # misal, ubah ke 4000 sample
#       5 dataset.set_input_window(window_length)
#
# File ~/anaconda3/envs/pickseisai/lib/python3.12/site-packages/seisbench/data/stead.py:27, in STEAD.__init__(self, **kwargs)
#      22 citation = (
#      23     "Mousavi, S. M., Sheng, Y., Zhu, W., Beroza G.C., (2019). STanford EArthquake Dataset (STEAD): "
#      24     "A Global Data Set of Seismic Signals for AI, IEEE Access, doi:10.1109/ACCESS.2019.2947848"
#      25 )
#      26 license = "CC BY 4.0"
# ---> 27 super().__init__(
# ...
